# %% [markdown]
# # We'll be analysing  Sales Report

# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

# %%
df = pd.read_excel('sales.xlsx')
df.head()
# Out:
#    Row ID  Order ID Order Date Order Priority  Order Quantity       Sales  \
# 0     1.0       3.0 2010-10-13            Low             6.0    261.5400
# 1    49.0     293.0 2012-10-01           High            49.0  10123.0200
# 2    50.0     293.0 2012-10-01           High            27.0    244.5700
# 3    80.0     483.0 2011-07-10           High            30.0   4965.7595
# 4    85.0     515.0 2010-08-28  Not Specified            19.0    394.2700
#
#    Discount       Ship Mode     Profit  Unit Price  ...       Customer Name  \
# 0      0.04     Regular Air  -213.2500       38.94  ...  Muhammed MacIntyre
# 1      0.07  Delivery Truck   457.8100      208.16  ...        Barry French
# 2      0.01     Regular Air    46.7075        8.69  ...        Barry French
# 3      0.08     Regular Air  1198.9710      195.99  ...       Clay Rozendal
# 4      0.08     Regular Air    30.9400       21.78  ...      Carlos Soltero
#
#   Province   Region Customer Segment Product Category  \
# ...

# %%
sns.relplot(x='Sales',y='Profit',data=df, hue= 'Ship Mode', style = 'Order Priority')

# %% [markdown]
# ## We developed to scratter plot between sales & profit
# and we have noticed that we even have negative profit sales as well.
# Orange color is most dominating here & this gives a message to Logistics team
# that most of the orders delivered through the Delivery Truck

# %%
sns.relplot(x='Sales',y='Profit',data=df, col= 'Ship Mode', hue= 'Product Category',col_wrap=3)

# %%
sns.relplot(x='Sales',y='Profit',data=df, col= 'Customer Segment',row='Product Category',hue = 'Ship Mode')

# %% [markdown]
# # Here we looked into each product category for each customer segment
# Findings through this chart:
# 1. Most of the Furniture category got transfered through Delivery Truck
# 2. Most of the office supplies got transfered through Express Air
# 3. Technology got transfered almost equality with Delivery Truck & Regular air

# %%
sns.catplot(x='Ship Mode', y='Sales',data=df.query('Profit>1000'),jitter=True)

# %% [markdown]
# # Scatter Plot where profit is greater than 1000 with shipping modes

# %%
sns.relplot(x='Order Date', y='Sales', data= df, kind ='line')

# %% [markdown]
# # Now we will be analysing data with the time period
# As we get messy timeline we need to do some data cleaning

# %%
df['year']= df['Order Date'].dt.year
df['year'].unique()
# Out:
# array([2010, 2012, 2011, 2009])

# %%
sns.relplot(x='year', y='Sales', data=df, kind='line')

# %%
sns.relplot(x='year', y='Sales', data=df, kind='line',ci=None)

# %%
sns.relplot(x='year', y='Sales', data=df, kind='line',hue='Ship Mode',col='Product Category',ci=None)

# %%
sns.relplot(x='year', y='Sales', data=df, kind='line',hue='Ship Mode',col='Region',ci=None, col_wrap=4)

# %% [markdown]
# # Here we can see the Year wise Sales report with Shipping mode & for each Region

# %%
sns.catplot(x= 'Product Category', y= 'Shipping Cost', data= df, kind= 'box')

# %% [markdown]
# ### Box plot showing the avg shipping cost for Furniture is higher compare to office supplies & Technology products

# %%
sns.catplot(x= 'Product Category', y= 'Shipping Cost', hue='Ship Mode', data= df, kind= 'box')

# %% [markdown]
# ### Drilled more into shipping cost for each shipping mode & Office supplies with delivery truck cost avg is higher than the furniture shippping cost delivered with delivery truck

# %%
sns.catplot(x= 'Product Category', y= 'Shipping Cost',hue='Ship Mode', col='Ship Mode', data= df, kind= 'box')

# %%
sns.catplot(x= 'Product Category', y= 'Shipping Cost',hue='Ship Mode', row='Customer Segment', col='Ship Mode', data= df, kind= 'box')

# %% [markdown]
# # More Macro details with each customer segment with each Ship Mode and we can see the outliers as well
# ##### Regular air having most of the outliser and cosumer segment with truck delivery of office supplies & tech prodcut have no outliers

# %%
sns.catplot(x= 'Product Category', y= 'Shipping Cost', data= df, kind= 'violin')

# %%
sns.catplot(x= 'Product Category', y= 'Sales', data= df, kind= 'bar')

# %% [markdown]
# ##### This Bar plot shows Furniture is the highest selling product 2nd is Tech & 3rd is office supplies

# %%
sns.catplot(x= 'Product Category', y= 'Sales',hue= 'Ship Mode', data= df, kind= 'bar')

# %%
b

# %%
sns.catplot(x= 'Product Category', y= 'Sales',hue= 'Ship Mode',col='Customer Segment', data= df, kind= 'point')

# %%
sns.distplot(x=df.Profit, kde= False)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:>

# %%
sns.kdeplot(df.Profit,bw=1)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:1699: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 1 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Profit', ylabel='Density'>

# %%
sns.jointplot(x='Sales',y='Product Base Margin',data=df, kind='hex')

# %%
sns.jointplot(x='Discount',y='Product Base Margin', data = df, kind='hex')

# %%
sns.pairplot(df, hue = 'Ship Mode')

# %%
df.corr()
# Out:
#                        Row ID  Order ID  Order Quantity     Sales  Discount  \
# Row ID               1.000000  0.999961        0.011103 -0.007560 -0.003289
# Order ID             0.999961  1.000000        0.010953 -0.007792 -0.003213
# Order Quantity       0.011103  0.010953        1.000000  0.220582 -0.009649
# Sales               -0.007560 -0.007792        0.220582  1.000000 -0.019686
# Discount            -0.003289 -0.003213       -0.009649 -0.019686  1.000000
# Profit              -0.006605 -0.006820        0.194655  0.581960 -0.037128
# Unit Price          -0.004115 -0.004304       -0.104284  0.602521  0.001332
# Shipping Cost       -0.004713 -0.004582       -0.011457  0.434578 -0.001956
# Product Base Margin -0.022726 -0.022557        0.007839  0.156759  0.004079
#
#                        Profit  Unit Price  Shipping Cost  Product Base Margin
# Row ID              -0.006605   -0.004115      -0.004713            -0.022726
# ...

# %%
sns.heatmap(df.corr(),cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Order Priority', 'Order Quantity',
#        'Sales', 'Discount', 'Ship Mode', 'Profit', 'Unit Price',
#        'Shipping Cost', 'Customer Name', 'Province', 'Region',
#        'Customer Segment', 'Product Category', 'Product Sub-Category',
#        'Product Name', 'Product Container', 'Product Base Margin',
#        'Ship Date'],
#       dtype='object')
