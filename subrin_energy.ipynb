# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'E:\196\energy-data\owid-energy-data.csv')

# %%
df.head()
# Out:
#        country  year iso_code  population  gdp  biofuel_cons_change_pct  \
# 0  Afghanistan  1900      AFG   4832414.0  NaN                      NaN
# 1  Afghanistan  1901      AFG   4879685.0  NaN                      NaN
# 2  Afghanistan  1902      AFG   4935122.0  NaN                      NaN
# 3  Afghanistan  1903      AFG   4998861.0  NaN                      NaN
# 4  Afghanistan  1904      AFG   5063419.0  NaN                      NaN
#
#    biofuel_cons_change_twh  biofuel_cons_per_capita  biofuel_consumption  \
# 0                      NaN                      NaN                  NaN
# 1                      NaN                      NaN                  NaN
# 2                      NaN                      NaN                  NaN
# 3                      NaN                      NaN                  NaN
# 4                      NaN                      NaN                  NaN
#
#    biofuel_elec_per_capita  ...  solar_share_elec  solar_share_energy  \
# ...

# %%
df2= df.loc[df['country'] == 'World']
df2.head()
# Out:
#       country  year iso_code    population           gdp  \
# 21844   World  1900      NaN  1.647405e+09  3.405759e+12
# 21845   World  1901      NaN  1.658786e+09           NaN
# 21846   World  1902      NaN  1.672564e+09           NaN
# 21847   World  1903      NaN  1.687013e+09           NaN
# 21848   World  1904      NaN  1.701647e+09           NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 21844                      NaN                      NaN
# 21845                      NaN                      NaN
# 21846                      NaN                      NaN
# 21847                      NaN                      NaN
# 21848                      NaN                      NaN
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 21844                      NaN                  NaN                      NaN
# 21845                      NaN                  NaN                      NaN
# ...

# %%
# %matplotlib inline
from cProfile import label
import matplotlib.pyplot as plt


plt.figure(figsize=(11, 7))
plt.plot( df2.year, df2.oil_consumption, label ='oil' )
plt.plot( df2.year, df2.coal_consumption, label ='coal')
plt.plot( df2.year, df2.gas_consumption, label ='gas')
plt.plot( df2.year, df2.hydro_consumption, label ='hydro')
plt.plot( df2.year, df2.nuclear_consumption, label ='nuclear')
plt.plot( df2.year, df2.biofuel_consumption, label ='biofuel')
plt.plot( df2.year, df2.wind_consumption, label ='wind')
plt.plot( df2.year, df2.solar_consumption, label ='solar')
plt.plot( df2.year, df2.other_renewable_consumption, label ='other_renewable')
plt.xlabel('Year')
plt.ylabel('TWh')



plt.legend()
plt.show()

# %%
df3 = df [ (df['country'] == 'United States') | (df['country']  == 'Europe') | (df['country']  == 'India') | (df['country']  == 'China')]

#list(df3.year.unique())
df3 = df3[ df3['year'] > 2020]

# %%
list(df3.country.unique())
# Out:
# ['China', 'Europe', 'India', 'United States']

# %%
df3.head()
# Out:
#              country  year iso_code    population  gdp  \
# 4283           China  2021      CHN  1.444216e+09  NaN
# 6516          Europe  2021      NaN  7.489630e+08  NaN
# 9136           India  2021      IND  1.393409e+09  NaN
# 21130  United States  2021      USA  3.329151e+08  NaN
#
#        biofuel_cons_change_pct  biofuel_cons_change_twh  \
# 4283                    25.274                    6.033
# 6516                       NaN                      NaN
# 9136                    20.318                    4.496
# 21130                    8.871                   33.559
#
#        biofuel_cons_per_capita  biofuel_consumption  biofuel_elec_per_capita  \
# 4283                    20.704               29.901                  114.498
# 6516                       NaN                  NaN                  281.870
# 9136                    19.109               26.627                   23.690
# 21130                 1237.193              411.880                  166.649
#
# ...

# %%
list(df3.year.unique())
# Out:
# [2021]

# %%
df3.drop(df3.columns.difference(['country',
'oil_consumption','coal_consumption',
'gas_consumption','hydro_consumption','nuclear_consumption',
'biofuel_consumption','wind_consumption','solar_consumption','other_renewable_consumption']), 1, inplace=True)


df3.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12844\514434184.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df3.drop(df3.columns.difference(['country',
#              country  biofuel_consumption  coal_consumption  gas_consumption  \
# 4283           China               29.901         23936.059         3786.944
# 6516          Europe                  NaN          3253.386        10073.819
# 9136           India               26.627          5580.151          621.678
# 21130  United States              411.880          2936.548         8267.174
#
#        hydro_consumption  nuclear_consumption  oil_consumption  \
# 4283            3401.680             1023.213         8499.583
# 6516            2116.456             2789.520         9087.600
# 9136             419.520              110.276         2612.807
# 21130            674.292             2056.739         9813.040
#
# ...

# %%
list(df3.columns)
# Out:
# ['country',
#  'biofuel_consumption',
#  'coal_consumption',
#  'gas_consumption',
#  'hydro_consumption',
#  'nuclear_consumption',
#  'oil_consumption',
#  'other_renewable_consumption',
#  'solar_consumption',
#  'wind_consumption']

# %%
#df3 = df3.fillna(0)
#df3.isnull().any()
#df3.shape

df3.head()
# Out:
#              country  biofuel_consumption  coal_consumption  gas_consumption  \
# 4283           China               29.901         23936.059         3786.944
# 6516          Europe                0.000          3253.386        10073.819
# 9136           India               26.627          5580.151          621.678
# 21130  United States              411.880          2936.548         8267.174
#
#        hydro_consumption  nuclear_consumption  oil_consumption  \
# 4283            3401.680             1023.213         8499.583
# 6516            2116.456             2789.520         9087.600
# 9136             419.520              110.276         2612.807
# 21130            674.292             2056.739         9813.040
#
#        other_renewable_consumption  solar_consumption  wind_consumption
# 4283                       542.367            855.653          1715.493
# 6516                       725.605            484.910          1242.021
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt


df3.plot.barh(
  #x = 'country', 
  #kind = 'barh', 
  stacked = True, 
  title = 'Primary energy consumption by source, 2021', 
  mark_right = True,
  figsize=(24, 8),
  fontsize=15,
 )
plt.legend(fontsize=15)
  
df3_total = df3["biofuel_consumption"] + df3["coal_consumption"] + df3["gas_consumption"] + df3["hydro_consumption"] + df3["nuclear_consumption"] + df3["oil_consumption"]+ df3["other_renewable_consumption"] + df3["solar_consumption"] + df3["wind_consumption"]
df3_rel = df[df3.columns[1:]].div(df3_total, 0)*100
